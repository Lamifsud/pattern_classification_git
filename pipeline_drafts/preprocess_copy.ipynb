# %%
#from structure_and_load import load
import matplotlib.pyplot as plt 
import numpy as np
import pandas as pd
import scipy.ndimage as spn 
import seaborn as sns
from itertools import combinations
import itertools

from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import HistGradientBoostingClassifier
from sklearn.model_selection import StratifiedShuffleSplit
from sklearn.pipeline import make_pipeline

from open_data  import matlab_file
from structure_data import  manage
from measures import ISI, FiringRate, tools
from classify import HistGrad

import re
import neo 
from neo.core import Event
from quantities import s 
from quantities import millisecond as ms


import os
import sys

# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Load and format data

# %% [markdown]
# ### Load data

# %%
lab_desktop = True
if lab_desktop : 
    result_path = '/home/INT/mifsud.l/Bureau/pattern_classification_git/results/'

else : 
    result_path = '/home/laurie/Bureau/pattern_classification_git/results/'

# %%
data_path
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 data_path
#
# NameError: name 'data_path' is not defined

# %%
#Load
#session = 't150204001'
session = 'Mo180412002'
monkey = 'Mourad'
session, data_path, info_path = matlab_file.from_lab(lab_desktop=lab_desktop, session=session, monkey='Mourad')
# Out:
# Mo180412002 /home/INT/mifsud.l/Bureau/data/Mourad/Mo180412002/modified_data/ /home/INT/mifsud.l/Bureau/Lists&Documentation/MouradLaminarSpikes_May2024.xlsx

# %%
data, load_info = matlab_file.open(data_path)
# Out:
# 36 files loaded

# %%
load_info
# Out:
# [(0, 'Mo180412002_probe1_contact10_unit1.mat'),
#  (1, 'Mo180412002_probe1_contact30_unit2.mat'),
#  (2, 'Mo180412002_probe1_contact30_unit1.mat'),
#  (3, 'Mo180412002_probe1_contact24_unit1.mat'),
#  (4, 'Mo180412002_probe1_contact10_unit4.mat'),
#  (5, 'Mo180412002_probe1_contact19_unit1.mat'),
#  (6, 'Mo180412002_probe1_contact32_unit2.mat'),
#  (7, 'Mo180412002_probe1_contact5_unit2.mat'),
#  (8, 'Mo180412002_probe1_contact8_unit1.mat'),
#  (9, 'Mo180412002_probe1_contact12_unit1.mat'),
#  (10, 'Mo180412002_probe1_contact18_unit3.mat'),
#  (11, 'Mo180412002_probe1_contact32_unit1.mat'),
#  (12, 'Mo180412002_probe1_contact20_unit3.mat'),
#  (13, 'Mo180412002_probe1_contact25_unit2.mat'),
#  (14, 'Mo180412002_probe1_contact26_unit1.mat'),
#  (15, 'Mo180412002_probe1_contact18_unit2.mat'),
#  (16, 'Mo180412002_probe1_contact19_unit2.mat'),
#  (17, 'Mo180412002_probe1_contact25_unit1.mat'),
#  (18, 'Mo180412002_probe1_contact20_unit1.mat'),
#  (19, 'Mo180412002_probe1_contact8_unit2.mat'),
#  (20, 'Mo180412002_probe1_contact11_unit1.mat'),
#  (21, 'Mo180412002_probe1_contact18_unit1.mat'),
#  (22, 'Mo180412002_probe1_contact22_unit1.mat'),
#  (23, 'Mo180412002_probe1_contact15_unit1.mat'),
#  (24, 'Mo180412002_probe1_contact17_unit1.mat'),
#  (25, 'Mo180412002_probe1_contact6_unit1.mat'),
#  (26, 'Mo180412002_probe1_contact5_unit1.mat'),
#  (27, 'Mo180412002_probe1_contact13_unit1.mat'),
#  (28, 'Mo180412002_probe1_contact20_unit2.mat'),
#  (29, 'Mo180412002_probe1_contact21_unit1.mat'),
#  (30, 'Mo180412002_probe1_contact23_unit2.mat'),
#  (31, 'Mo180412002_probe1_contact10_unit2.mat'),
#  (32, 'Mo180412002_probe1_contact21_unit2.mat'),
#  (33, 'Mo180412002_probe1_contact23_unit1.mat'),
#  (34, 'Mo180412002_probe1_contact28_unit1.mat'),
#  (35, 'Mo180412002_probe1_contact9_unit1.mat')]

# %%
session_info_raw = matlab_file.clean(info_path)

# %%
# get sessions and units information (unit, prob, elitrials)
info_units,  info_session = manage.info(load_info, session_info_raw, session)
unit_label, unit_labelProbe1, unit_labelProbe2, count_unitProbe = manage.units_label(info_units)
# manage elitrials format
info_session['elitrials'] = info_session['elitrials'].apply(manage.elitrials)
info_session.to_csv(result_path + f'{session}_info_session.csv')

# %%
#info_session
float_column_names = info_session.select_dtypes(include=['float']).columns
info_session[float_column_names] = info_session[float_column_names].astype(int)
info_session
# Out:
#     Plexon_spike_file  probe  channel  unit  start  stop  \
# 155       Mo180412002      1       10     1      1    14
# 184       Mo180412002      1       30     2      1    10
# 183       Mo180412002      1       30     1     11    14
# 178       Mo180412002      1       24     1      1    14
# 157       Mo180412002      1       10     4      1    14
# 168       Mo180412002      1       19     1      1    14
# 186       Mo180412002      1       32     2      1    14
# 150       Mo180412002      1        5     2      1     7
# 152       Mo180412002      1        8     1     11    14
# 160       Mo180412002      1       12     1      1    14
# 167       Mo180412002      1       18     3      1    14
# 185       Mo180412002      1       32     1      1    12
# 172       Mo180412002      1       20     3      1    14
# 180       Mo180412002      1       25     2      1    14
# 181       Mo180412002      1       26     1      1    14
# 166       Mo180412002      1       18     2      1    14
# 169       Mo180412002      1       19     2      1    14
# 179       Mo180412002      1       25     1      1    14
# 170       Mo180412002      1       20     1      1    14
# 153       Mo180412002      1        8     2      1    14
# 158       Mo180412002      1       11     1      1    14
# 165       Mo180412002      1       18     1      1    14
# 175       Mo180412002      1       22     1      1     7
# 162       Mo180412002      1       15     1      4    14
# 164       Mo180412002      1       17     1      1    11
# 151       Mo180412002      1        6     1      1    14
# 149       Mo180412002      1        5     1      1    14
# 161       Mo180412002      1       13     1      1     9
# 171       Mo180412002      1       20     2      9    14
# 173       Mo180412002      1       21     1      1    14
# 177       Mo180412002      1       23     2      1    14
# 156       Mo180412002      1       10     2      1    14
# 174       Mo180412002      1       21     2      1     3
# 176       Mo180412002      1       23     1      1    14
# 182       Mo180412002      1       28     1     10    14
# 154       Mo180412002      1        9     1      1    11
#
#      SUA (1), MUA (2), unstable (3) few trials (4) or observation (5)  \
# 155                                                  1
# 184                                                  1
# 183                                                  2
# 178                                                  2
# 157                                                  1
# 168                                                  2
# 186                                                  1
# 150                                                  1
# 152                                                  2
# 160                                                  1
# 167                                                  1
# 185                                                  1
# 172                                                  1
# 180                                                  2
# 181                                                  1
# 166                                                  1
# 169                                                  1
# 179                                                  1
# 170                                                  1
# 153                                                  1
# 158                                                  1
# 165                                                  1
# 175                                                  2
# 162                                                  1
# 164                                                  2
# 151                                                  1
# 149                                                  1
# 161                                                  1
# 171                                                  1
# 173                                                  1
# 177                                                  2
# 156                                                  1
# 174                                                  1
# 176                                                  1
# 182                                                  1
# 154                                                  1
#
#     elitrials
# 155        []
# 184        []
# 183        []
# 178        []
# 157        []
# 168        []
# 186        []
# 150        []
# 152        []
# 160        []
# 167        []
# 185        []
# 172        []
# 180        []
# 181        []
# 166        []
# 169        []
# 179        []
# 170        []
# 153        []
# 158        []
# 165        []
# 175        []
# 162        []
# 164        []
# 151        []
# 149        []
# 161        []
# 171        []
# 173        []
# 177        []
# 156        []
# 174        []
# 176        []
# 182        []
# 154        []

# %%
info_session
# Out:
#     Plexon_spike_file  probe  channel  unit  start  stop  \
# 155       Mo180412002      1       10     1      1    14
# 184       Mo180412002      1       30     2      1    10
# 183       Mo180412002      1       30     1     11    14
# 178       Mo180412002      1       24     1      1    14
# 157       Mo180412002      1       10     4      1    14
# 168       Mo180412002      1       19     1      1    14
# 186       Mo180412002      1       32     2      1    14
# 150       Mo180412002      1        5     2      1     7
# 152       Mo180412002      1        8     1     11    14
# 160       Mo180412002      1       12     1      1    14
# 167       Mo180412002      1       18     3      1    14
# 185       Mo180412002      1       32     1      1    12
# 172       Mo180412002      1       20     3      1    14
# 180       Mo180412002      1       25     2      1    14
# 181       Mo180412002      1       26     1      1    14
# 166       Mo180412002      1       18     2      1    14
# 169       Mo180412002      1       19     2      1    14
# 179       Mo180412002      1       25     1      1    14
# 170       Mo180412002      1       20     1      1    14
# 153       Mo180412002      1        8     2      1    14
# 158       Mo180412002      1       11     1      1    14
# 165       Mo180412002      1       18     1      1    14
# 175       Mo180412002      1       22     1      1     7
# 162       Mo180412002      1       15     1      4    14
# 164       Mo180412002      1       17     1      1    11
# 151       Mo180412002      1        6     1      1    14
# 149       Mo180412002      1        5     1      1    14
# 161       Mo180412002      1       13     1      1     9
# 171       Mo180412002      1       20     2      9    14
# 173       Mo180412002      1       21     1      1    14
# 177       Mo180412002      1       23     2      1    14
# 156       Mo180412002      1       10     2      1    14
# 174       Mo180412002      1       21     2      1     3
# 176       Mo180412002      1       23     1      1    14
# 182       Mo180412002      1       28     1     10    14
# 154       Mo180412002      1        9     1      1    11
#
#      SUA (1), MUA (2), unstable (3) few trials (4) or observation (5)  \
# 155                                                  1
# 184                                                  1
# 183                                                  2
# 178                                                  2
# 157                                                  1
# 168                                                  2
# 186                                                  1
# 150                                                  1
# 152                                                  2
# 160                                                  1
# 167                                                  1
# 185                                                  1
# 172                                                  1
# 180                                                  2
# 181                                                  1
# 166                                                  1
# 169                                                  1
# 179                                                  1
# 170                                                  1
# 153                                                  1
# 158                                                  1
# 165                                                  1
# 175                                                  2
# 162                                                  1
# 164                                                  2
# 151                                                  1
# 149                                                  1
# 161                                                  1
# 171                                                  1
# 173                                                  1
# 177                                                  2
# 156                                                  1
# 174                                                  1
# 176                                                  1
# 182                                                  1
# 154                                                  1
#
#     elitrials
# 155        []
# 184        []
# 183        []
# 178        []
# 157        []
# 168        []
# 186        []
# 150        []
# 152        []
# 160        []
# 167        []
# 185        []
# 172        []
# 180        []
# 181        []
# 166        []
# 169        []
# 179        []
# 170        []
# 153        []
# 158        []
# 165        []
# 175        []
# 162        []
# 164        []
# 151        []
# 149        []
# 161        []
# 171        []
# 173        []
# 177        []
# 156        []
# 174        []
# 176        []
# 182        []
# 154        []

# %%
# get unit's index without eli trials 
if monkey == 'Mourad':
    completeUnit = 0

elif monkey == 'Tommy':
    completeUnit = manage.CompleteTasktime(info_session, load_info, session)
unit_label[:5]
# Out:
# ['P1-10-1', 'P1-30-2', 'P1-30-1', 'P1-24-1', 'P1-10-4']

# %%
spike_times, task_times, target_info = matlab_file.extract_data2(\
        load_info, data, target_keys_OFF=['dirSC1', 'dirSC', 'dirSC3', 'ttype'],\
        target_keys_ON=['dirSC1', 'dirSC', 'dirSC3', 'ttype'], \
        event_keys_OFF=[])
        #event_keys_OFF=['Sel_OFF', 'SC1_OFF', 'SC2_OFF', 'SC3_OFF']

# %%
task_times[0][1].keys()
# Out:
# dict_keys(['TouchTime', 'SelTim', 'SelOffTim', 'SC1Tim', 'SC1OffTim', 'SC2Tim', 'SC2OffTim', 'SC3Tim', 'SC3OffTim', 'GoTim', 'TargTim'])

# %% [markdown]
# ### Format spike times

# %%
event_labels = matlab_file.get_event_labels(task_times)
event_times = matlab_file.get_event_times(task_times, event_labels)
# reshape times by trials / periods for each neuron + Neo format
trials_ts, df_task_ts_by_neuron, events = manage.events_by_trial(event_times, event_labels)

# %%
np.save(result_path + f'{session}_event_labels.npy', event_labels)

# %%
unit_ = 0
trial_ = 12
print(f'times as list : {trials_ts[unit_][1][trial_]}')
print(f'times as neo events : {events[unit_][1][trial_].times}')
print(f'spike train sample : {spike_times[0][1]}\nevents : {event_labels}\ntargets : {task_times[0][1].keys()}')
# Out:
# times as list : [159779 160963 161270 162329 162645 163646 163967 164968 165275 166253
#  166800]
# times as neo events : [159779. 160963. 161270. 162329. 162645. 163646. 163967. 164968. 165275.
#  166253. 166800.] ms
# spike train sample : [     41      95     355 ... 3388428 3388617 3388863]
# events : ['TouchTime', 'SelTim', 'SelOffTim', 'SC1Tim', 'SC1OffTim', 'SC2Tim', 'SC2OffTim', 'SC3Tim', 'SC3OffTim', 'GoTim', 'TargTim']
# targets : dict_keys(['TouchTime', 'SelTim', 'SelOffTim', 'SC1Tim', 'SC1OffTim', 'SC2Tim', 'SC2OffTim', 'SC3Tim', 'SC3OffTim', 'GoTim', 'TargTim'])

# %%
# get dataframe with each events times per trials for a complete session
t = 0
tot_trials_in_task = trials_ts[completeUnit][1].shape[0]
df_task_ts = pd.DataFrame(trials_ts[completeUnit][1], columns=event_labels, index=np.arange(0, tot_trials_in_task))
df_task_ts.tail()
# Out:
#      TouchTime   SelTim  SelOffTim   SC1Tim  SC1OffTim   SC2Tim  SC2OffTim  \
# 215    3317250  3318367    3318674  3319675    3319982  3320984    3321294
# 216    3327845  3328900    3329207  3330208    3330515  3331517    3331823
# 217    3343307  3344385    3344693  3345694    3346001  3347002    3347309
# 218    3353627  3354692    3354998  3355999    3356320  3357321    3357641
# 219    3364653  3365731    3366038  3367066    3367373  3368374    3368681
#
#       SC3Tim  SC3OffTim    GoTim  TargTim
# 215  3322292    3322599  3323577  3324165
# 216  3332825    3333132  3334110  3334657
# 217  3348310    3348617  3349595  3350102
# 218  3358670    3358990  3359967  3360689
# 219  3369685    3370003  3370981  3371541

# %%
event_vector = df_task_ts.loc[t] - df_task_ts.iloc[t,0]
#event_vector = event_vector.values
event_vector = event_vector.iloc[:11].values
print(event_vector)
np.save(result_path + f'{session}_event_vector.npy', event_vector)
# Out:
# [   0 1082 1390 2391 2698 3699 4049 5061 5381 6359 6843]

# %% [markdown]
# ### Format target

# %%
target_info[0][1].keys()
# Out:
# dict_keys(['dirSC1', 'dirSC', 'dirSC3', 'ttype'])

# %%
target = manage.target_by_trials2(target_info, completeUnit)
target.to_csv(result_path + 'target.csv')
target
# Out:
#      trial_type  position  type_and_pos
# 0             1         3             2
# 1             1         1             0
# 2             1         2             1
# 3             1         4             3
# 4             1         1             0
# ..          ...       ...           ...
# 215           1         2             1
# 216           2         3             6
# 217           2         1             4
# 218           2         4             7
# 219           2         2             5
#
# [220 rows x 3 columns]

# %% [markdown]
# ### Format trials

# %%
# align times by trials for each neurons
df_task_ts_by_neuron = manage.time_by_trials(df_task_ts_by_neuron, df_task_ts, event_labels)
df_task_ts_by_neuron[0][1]

# split the spike time vector by trial
spk_trials, spike_train_trial = manage.spike_ts_by_trial(trials_ts, spike_times)
spikes_times_aligned = manage.spike_ts_aligned(df_task_ts, df_task_ts_by_neuron, spike_times, unit_label, spike_train_trial)
# Out:
# /home/INT/mifsud.l/Bureau/pattern_classification_git/pipeline_drafts/structure_data/manage.py:402: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   t_start = data.iloc[idx_trial_valid][1]
# /home/INT/mifsud.l/Bureau/pattern_classification_git/pipeline_drafts/structure_data/manage.py:403: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   t_stop = data.iloc[idx_trial_valid][-1]
# /home/INT/mifsud.l/Bureau/pattern_classification_git/pipeline_drafts/structure_data/manage.py:425: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   t_start_nan = df_task_ts.iloc[idx_trial_nan][0]
# /home/INT/mifsud.l/Bureau/pattern_classification_git/pipeline_drafts/structure_data/manage.py:426: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   t_stop_nan = df_task_ts.iloc[idx_trial_nan][-1]

# %% [markdown]
# # Raster plot

# %%
n_neurons = spikes_times_aligned.shape[0]

t = 0
event_vector = df_task_ts.loc[t]

plt.figure(figsize=(30, 10))  # Ajustez la taille de la figure selon vos besoins

# Parcourir tous les neurones et tracer leur spike train
for n in range(n_neurons): 
    spiketrain = spikes_times_aligned[n][t]['spike_train']
    if len(spiketrain) > 0 and spiketrain[0] != 0:      
        plt.eventplot(spiketrain.magnitude, linelengths=0.75, lineoffsets=n, color='black')
for i in range(n_neurons - 1):
    plt.hlines(i+0.5, xmin=event_vector.min(), xmax=event_vector.max(), colors='gray', linestyles='solid', linewidth=0.5)

# Définir les étiquettes de l'axe x et l'axe y
plt.xticks(event_vector.values, event_labels, fontsize=7)
plt.yticks(range(n_neurons), [f"{i}" for i in range(n_neurons)], fontsize=8)
plt.title(f"Spike Trains for Trial {t}", fontsize=16)

# Ajuster les limites des axes
plt.xlim(event_vector.min(), event_vector.max())
plt.ylim(-0.5, 42.5)

plt.show()

# %% [markdown]
# # Compute measure

# %%
def destroy_corr(x, y):
    rng = np.random.default_rng() #ramdom seed
    n_samples, n_times, n_feat = x.shape 
    y_u = np.unique(y)
    x_dc = x.copy()

    for n_y in y_u:
        is_class = y == n_y
        x_dc[is_class, :, :] = rng.permuted(x[is_class, :, :], axis=0)
    return x_dc

# %% [markdown]
# ## Instantaneous Firing rate

# %%
sigma = [10]
max_length = tools.get_max_length_trials(spikes_times_aligned[-1])
spikes_binarized = FiringRate.binarize_spike_times(spikes_times_aligned, max_length)
spike_convolved = FiringRate.convolve_spike_binarized(spikes_binarized, sigma)




##########
spike_convolved = spike_convolved[:,0:6500, :]
plt.figure(figsize=(20,4))
plt.plot(spikes_binarized[128,:,0])
plt.plot(spike_convolved[128,:,0])
np.save(result_path + f'{session}_spike_convolved.npy', spike_convolved)

# %% [markdown]
# ## Instantaneous Shuffled Firing rate

# %%
n_trials, n_times, n_neurons = spike_convolved.shape
spike_convolved_shuff_tt = np.zeros((n_trials, n_times, n_neurons))
spike_convolved_shuff_pos = np.zeros((n_trials, n_times, n_neurons))
list_idx_tt = []
list_idx_pos = []

for t, idx, in target.groupby(['trial_type']).groups.items():
    idx = idx.values
    list_idx_tt.append(idx)

spike_convolved_shuff_tt = destroy_corr(spike_convolved, target['trial_type'].values)

for t, idx, in target.groupby(['position']).groups.items():
    idx = idx.values
    list_idx_pos.append(idx)

spike_convolved_shuff_pos = destroy_corr(spike_convolved, target['position'].values)

# %%
plt.figure(figsize=(20,4))
plt.plot(spike_convolved[list_idx_tt[2],:,:].mean(axis=(0,2)), label='firing rate')
plt.plot(spike_convolved_shuff_tt[list_idx_tt[2],:,:].mean(axis=(0,2)), label='shuffled firing rate')
plt.legend();

# %%
plt.figure(figsize=(20,4))
plt.plot(spike_convolved[list_idx_pos[2],:,:].mean(axis=(0,2)), label='firing rate')
plt.plot(spike_convolved_shuff_pos[list_idx_pos[2],:,:].mean(axis=(0,2)), label='shuffled firing rate')
plt.legend();

# %%
np.save(result_path + f'{session}_spike_convol_shuff_tt.npy', spike_convolved_shuff_tt)
np.save(result_path + f'{session}_spike_convol_shuff_pos.npy', spike_convolved_shuff_pos)

# %% [markdown]
# ## Instantaneous Synchrony

# %%
# Étape 1: Créer un dictionnaire pour mapper les labels d'unité à leur Probe et channel correspondants
unit_mapping = {}
for label in unit_label:
    probe, channel, _ = label.split('-')
    unit_mapping[label] = (probe, int(channel))

# Étape 2: Créer une liste de toutes les paires de neurones possibles
neuron_pairs = list(itertools.combinations(unit_label, 2))


# Étape 3: Filtrer les paires de neurones qui sont sur la même Probe mais pas sur la même channel
filtered_neuron_pairs = []
for pair in neuron_pairs:
    probe1, channel1 = unit_mapping[pair[0]]
    probe2, channel2 = unit_mapping[pair[1]]
    if probe1 != probe2 :
        filtered_neuron_pairs.append((unit_label.index(pair[0]), unit_label.index(pair[1])))
    elif probe1 == probe2 and channel1 != channel2:
        filtered_neuron_pairs.append((unit_label.index(pair[0]), unit_label.index(pair[1])))
        
n_pairs = len(filtered_neuron_pairs)
# Créer une matrice pour stocker les résultats de la synchronie filtrée
filtered_Synch = np.zeros((n_trials, n_times, n_pairs))

# Calculer la synchronie pour chaque paire filtrée
for i, (r, c) in enumerate(filtered_neuron_pairs):
    for t in range(n_trials):
        filtered_Synch[t, :, i] = spike_convolved[t, :, r] * spike_convolved[t, :, c]

n0 = 0
n1 = 2
neurons_ = [n0,n1]
plt.figure(figsize=(20,4))
plt.plot(spike_convolved[121,:,n0], label=f'fr convol {n0}')
plt.plot(spike_convolved[121,:,n1], label=f'fr convol {n1}')
plt.plot(filtered_Synch[121,:,1], label='synchrony')
plt.legend()


np.save(result_path + f'{session}_synchrony.npy', filtered_Synch)

# %% [markdown]
# # Shuffled synchrony

# %%
n_shuff = 10
list_shuffled_sync_tt = []
list_shuffled_sync_pos = []

filtered_Synch_shuff_tt = np.zeros((n_trials, n_times, n_pairs), dtype=np.float32)
filtered_Synch_shuff_pos = np.zeros((n_trials, n_times, n_pairs), dtype=np.float32)


# Calculer la synchronie pour chaque paire filtrée


for i, (r, c) in enumerate(filtered_neuron_pairs):
    for t in range(n_trials):
        filtered_Synch_shuff_tt[t, :, i] = spike_convolved[t, :, r] * spike_convolved_shuff_tt[t, :, c]
        filtered_Synch_shuff_pos[t, :, i] = spike_convolved[t, :, r] * spike_convolved_shuff_pos[t, :, c]
        
list_shuffled_sync_tt.append(filtered_Synch_shuff_tt)
list_shuffled_sync_pos.append(filtered_Synch_shuff_pos)

#list_shuffled_sync = np.array(list_shuffled_sync)
np.save(result_path + f'{session}_synchrony_shuff_tt.npy', filtered_Synch_shuff_tt)
np.save(result_path + f'{session}_synchrony_shuff_pos.npy', filtered_Synch_shuff_pos)

# %%
a

# %%
# Import the pickle module
import pickle

# Open a file for writing
file_object_tt = open(f'{result_path}list_shuffled_sync_tt.pkl', 'wb')
file_object_pos = open(f'{result_path}list_shuffled_sync_pos.pkl', 'wb')
# Dump the list into the file
pickle.dump(list_shuffled_sync_tt, file_object_tt)
pickle.dump(list_shuffled_sync_pos, file_object_pos)


# Close the file
file_object_tt.close()
file_object_pos.close()

# %%
for i in range(len(list_idx_tt)):
    plt.figure(figsize=(20,4))
    plt.plot(filtered_Synch[list_idx_tt[i],:,:].mean(axis=(0,2)), label='synchrony')
    plt.plot(filtered_Synch_shuff[list_idx_tt[i],:,:].mean(axis=(0,2)), label='shuffled synchrony')
    plt.legend();

# %%
event_vector
# Out:
# TouchTime    18897
# SelTim       19979
# SelOffTim    20287
# SC1Tim       21288
# SC1OffTim    21595
# SC2Tim       22596
# SC2OffTim    22946
# SC3Tim       23958
# SC3OffTim    24278
# GoTim        25256
# TargTim      25740
# Name: 0, dtype: int64

# %%
plt.imshow(np.isnan(spike_convolved[:,:,0]))
